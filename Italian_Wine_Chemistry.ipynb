# %% [markdown]
# Link to dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
col = df.iloc[:,[0,3,6,8,10,12,13]]
col
# Out:
#      1  2.43   2.8   .28   5.64  3.92  1065
# 0    1  2.14  2.65  0.26   4.38  3.40  1050
# 1    1  2.67  2.80  0.30   5.68  3.17  1185
# 2    1  2.50  3.85  0.24   7.80  3.45  1480
# 3    1  2.87  2.80  0.39   4.32  2.93   735
# 4    1  2.45  3.27  0.34   6.75  2.85  1450
# ..  ..   ...   ...   ...    ...   ...   ...
# 172  3  2.45  1.68  0.52   7.70  1.74   740
# 173  3  2.48  1.80  0.43   7.30  1.56   750
# 174  3  2.26  1.59  0.43  10.20  1.56   835
# 175  3  2.37  1.65  0.53   9.30  1.62   840
# 176  3  2.74  2.05  0.56   9.20  1.60   560
#
# [177 rows x 7 columns]

# %%
df = df.drop(columns = col)
df
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 2. Assign the columns as below: - alcohol - malic_acid - alcalinity_of_ash - magnesium - flavanoids - proanthocyanins - hue.

# %%
df.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
df.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### 3. Set the values of the first 3 rows in the alcohol column as NaN.

# %%
df.loc[:2, 'alcohol'] = np.nan
df.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
# 5    14.39        1.87               14.6         96        2.52
# 6    14.06        2.15               17.6        121        2.51
# 7    14.83        1.64               14.0         97        2.98
# 8    13.86        1.35               16.0         98        3.15
# 9    14.10        2.16               18.0        105        3.32
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# ...

# %% [markdown]
# ### 4. Now set the value of the rows 3 and 4 of the magnesium column as NaN

# %%
df.loc[2:3, 'magnesium'] = np.nan
df.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7    14.83        1.64               14.0       97.0        2.98
# 8    13.86        1.35               16.0       98.0        3.15
# 9    14.10        2.16               18.0      105.0        3.32
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# ...

# %% [markdown]
# ### 5. Fill in the null values (NaN) with the number 10 in the alcohol column and 100 in magnesium column.

# %%
df['alcohol'] = df['alcohol'].replace(np.nan, 10)
df.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
df.loc[2:3, 'magnesium'] = 100
df.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### 6. Count the number of missing values in the entire dataset.

# %%
df.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# #### There are no missing values in the dataframe.
