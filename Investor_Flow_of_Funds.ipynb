# %% [markdown]
# Link to dataset: https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
df.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2012-12-05         -7426            -6060         -1367     -74
# 1  2012-12-12         -8783            -7520         -1263     123
# 2  2012-12-19         -5496            -5470           -26     -73
# 3  2012-12-26         -4451            -4076          -375     550
# 4  2013-01-02        -11156            -9622         -1533    -158
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0        5317          4210            1107  -2183
# 1        1818          1598             219  -6842
# 2         103          3472           -3369  -5466
# 3        2610          3333            -722  -1291
# 4        2383          2103             280  -8931

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             44 non-null     object
#  1   Total Equity     44 non-null     int64
#  2   Domestic Equity  44 non-null     int64
#  3   World Equity     44 non-null     int64
#  4   Hybrid           44 non-null     int64
#  5   Total Bond       44 non-null     int64
#  6   Taxable Bond     44 non-null     int64
#  7   Municipal Bond   44 non-null     int64
#  8   Total            44 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 3.2+ KB

# %%
df.shape
# Out:
# (44, 9)

# %%
df.nunique()
# Out:
# Date               44
# Total Equity       44
# Domestic Equity    44
# World Equity       44
# Hybrid             44
# Total Bond         44
# Taxable Bond       44
# Municipal Bond     43
# Total              44
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date               0
# Total Equity       0
# Domestic Equity    0
# World Equity       0
# Hybrid             0
# Total Bond         0
# Taxable Bond       0
# Municipal Bond     0
# Total              0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#               Date  Total Equity  Domestic Equity  World Equity       Hybrid  \
# count           44     44.000000        44.000000     44.000000    44.000000
# unique          44           NaN              NaN           NaN          NaN
# top     2012-12-05           NaN              NaN           NaN          NaN
# freq             1           NaN              NaN           NaN          NaN
# mean           NaN   -161.727273     -1815.931818   1654.227273   684.227273
# std            NaN   4318.401639      3223.717184   1533.770151   670.325983
# min            NaN -11156.000000     -9622.000000  -1533.000000 -1057.000000
# 25%            NaN  -1758.500000     -3385.750000    883.250000   249.500000
# 50%            NaN    476.000000     -1774.000000   1563.500000   791.500000
# 75%            NaN   1916.500000       -22.000000   2561.500000  1072.000000
# max            NaN  14817.000000      7995.000000   6821.000000  2888.000000
#
# ...

# %% [markdown]
# ### 1. What is the frequency of the dataset? (The time period between each row)

# %%
time_diff = pd.to_datetime(df['Date']).diff().dt.days
time_diff
# Out:
# 0       NaN
# 1       7.0
# 2       7.0
# 3       7.0
# 4       7.0
# 5       7.0
# 6     448.0
# 7       7.0
# 8       7.0
# 9       7.0
# 10      7.0
# 11      7.0
# 12      7.0
# 13      7.0
# 14      7.0
# 15      7.0
# 16      7.0
# 17      7.0
# 18      7.0
# 19      7.0
# 20      7.0
# 21     21.0
# 22      7.0
# 23      7.0
# 24      7.0
# 25      7.0
# 26      7.0
# 27      7.0
# 28     56.0
# 29      7.0
# 30      7.0
# 31      6.0
# 32     43.0
# 33      7.0
# 34      7.0
# 35      7.0
# 36      7.0
# 37      7.0
# 38     21.0
# 39      7.0
# 40      7.0
# 41      7.0
# 42      7.0
# 43      7.0
# Name: Date, dtype: float64

# %% [markdown]
# ### 2. What is the data type of the Date?

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Data type of the Date Column is Object.

# %% [markdown]
# ### 3. Set the index to a Datetime.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index(df['Date'])
df
# Out:
#                  Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# Date
# 2012-12-05 2012-12-05         -7426            -6060         -1367     -74
# 2012-12-12 2012-12-12         -8783            -7520         -1263     123
# 2012-12-19 2012-12-19         -5496            -5470           -26     -73
# 2012-12-26 2012-12-26         -4451            -4076          -375     550
# 2013-01-02 2013-01-02        -11156            -9622         -1533    -158
# 2013-01-09 2013-01-09         14817             7995          6821    2888
# 2014-04-02 2014-04-02          3155              938          2217     265
# 2014-04-09 2014-04-09          5761             2080          3681    1482
# 2014-04-16 2014-04-16          2286              634          1652    1186
# 2014-04-23 2014-04-23          3530             1392          2138    1239
# 2014-04-30 2014-04-30         -3890            -3996           106     759
# ...

# %% [markdown]
# ### 4. Change the frequency to monthly, sum the values and assign it to new variable called monthly.

# %%
monthly = df.resample('M', on = 'Date').sum()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31        -26156           -23126         -3031     526        9848
# 2013-01-31          3661            -1627          5288    2730       12149
# 2013-02-28             0                0             0       0           0
# 2013-03-31             0                0             0       0           0
# 2013-04-30             0                0             0       0           0
# 2013-05-31             0                0             0       0           0
# 2013-06-30             0                0             0       0           0
# 2013-07-31             0                0             0       0           0
# 2013-08-31             0                0             0       0           0
# 2013-09-30             0                0             0       0           0
# 2013-10-31             0                0             0       0           0
# ...

# %% [markdown]
# ### 5. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly = monthly.replace(0, np.nan).dropna()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31      -26156.0         -23126.0       -3031.0   526.0      9848.0
# 2013-01-31        3661.0          -1627.0        5288.0  2730.0     12149.0
# 2014-04-30       10842.0           1048.0        9794.0  4931.0      8493.0
# 2014-05-31       -2203.0          -8720.0        6518.0  3172.0     13767.0
# 2014-06-30        2319.0          -6546.0        8865.0  4588.0      9715.0
# 2014-07-31       -7051.0         -11128.0        4078.0  2666.0      7506.0
# 2014-08-31        1943.0          -5508.0        7452.0  1885.0      1897.0
# 2014-09-30       -2767.0          -6596.0        3829.0  1599.0      3984.0
# 2014-11-30       -2753.0          -7239.0        4485.0   729.0     14528.0
# 2015-01-31        3471.0          -1164.0        4635.0  1729.0      7368.0
# 2015-02-28        5508.0           3509.0        1999.0  1752.0      9099.0
# ...

# %% [markdown]
# ### 6. Good, now we have the monthly data. Now change the frequency to year and assign to a new variable called year.

# %%
yearly = monthly.resample('Y').sum()
yearly
# Out:
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2012-12-31      -26156.0         -23126.0       -3031.0    526.0      9848.0
# 2013-12-31        3661.0          -1627.0        5288.0   2730.0     12149.0
# 2014-12-31         330.0         -44689.0       45021.0  19570.0     59890.0
# 2015-12-31       15049.0         -10459.0       25508.0   7280.0     26028.0
#
#             Taxable Bond  Municipal Bond    Total
# Date
# 2012-12-31       12613.0         -2765.0 -15782.0
# 2013-12-31        9414.0          2735.0  18540.0
# 2014-12-31       44994.0         14896.0  79787.0
# 2015-12-31       17986.0          8041.0  48357.0

# %% [markdown]
# ### 7. View the summary statistics of the monthly and yearly data.

# %%
monthly.describe()
# Out:
#        Total Equity  Domestic Equity  World Equity       Hybrid    Total Bond  \
# count     13.000000        13.000000     13.000000    13.000000     13.000000
# mean    -547.384615     -6146.230769   5598.923077  2315.846154   8301.153846
# std     8967.850807      6572.480267   4045.609687  1359.745984   4207.530290
# min   -26156.000000    -23126.000000  -3031.000000   526.000000    423.000000
# 25%    -2753.000000     -8176.000000   4078.000000  1599.000000   7368.000000
# 50%     1943.000000     -6546.000000   5007.000000  1885.000000   9099.000000
# 75%     3661.000000     -1627.000000   7452.000000  2829.000000   9848.000000
# max    10842.000000      3509.000000  13867.000000  4931.000000  14528.000000
#
#        Taxable Bond  Municipal Bond         Total
# count     13.000000       13.000000     13.000000
# mean    6539.000000     1762.076923  10069.384615
# std     4192.186442     1851.026133  10425.253446
# min    -1013.000000    -2765.000000 -15782.000000
# ...

# %%
yearly.describe()
# Out:
#        Total Equity  Domestic Equity  World Equity        Hybrid  \
# count      4.000000         4.000000      4.000000      4.000000
# mean   -1779.000000    -19975.250000  18196.500000   7526.500000
# std    17430.444573     18689.693744  21527.098899   8507.253121
# min   -26156.000000    -44689.000000  -3031.000000    526.000000
# 25%    -6291.500000    -28516.750000   3208.250000   2179.000000
# 50%     1995.500000    -16792.500000  15398.000000   5005.000000
# 75%     6508.000000     -8251.000000  30386.250000  10352.500000
# max    15049.000000     -1627.000000  45021.000000  19570.000000
#
#          Total Bond  Taxable Bond  Municipal Bond         Total
# count      4.000000      4.000000        4.000000      4.000000
# mean   26978.750000  21251.750000     5726.750000  32725.500000
# std    23075.516482  16218.506762     7538.595907  40879.230835
# min     9848.000000   9414.000000    -2765.000000 -15782.000000
# ...
