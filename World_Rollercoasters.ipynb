# %% [markdown]
# Link to dataset: https://buff.ly/3k6woDG

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://buff.ly/3k6woDG')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.nunique()
# Out:
# coaster_name                     990
# Length                           569
# Speed                            243
# Location                         280
# Status                            15
# Opening date                     656
# Type                              98
# Manufacturer                     102
# Height restriction               100
# Model                            317
# Height                           382
# Inversions                        12
# Lift/launch system               116
# Cost                             272
# Trains                           221
# Park section                     271
# Duration                         208
# Capacity                         160
# G-force                           70
# Designer                         153
# Max vertical angle                83
# Drop                             235
# Soft opening date                 84
# Fast Lane available                1
# Replaced                         140
# ...

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### 1. How many columns and rows are in the dataset?

# %%
df.shape
# Out:
# (1087, 56)

# %% [markdown]
# #### There are 1087 rows and 56 columns in dataset.

# %% [markdown]
# ### 2. Is there any missing data?

# %%
df.isnull().sum().sum()
# Out:
# 29435

# %% [markdown]
# #### There are 29,435 null values accross several columns.

# %% [markdown]
# ### 3. Display the summary statistics of the numeric columns using the describe method.

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### 4. Rename the following columns:
#
# coaster_name ➡️ Coaster_Name
#
# year_introduced ➡️ Year_Introduced
#
# opening_date_clean ➡️ Opening_Date
#
# speed_mph ➡️ Speed_mph
#
# height_ft ➡️ Height_ft
#
# Inversions_clean ➡️ Inversions
#
# Gforce_clean ➡️ Gforce

# %%
df.rename(columns = {'coaster_name':'Coaster_Name', 'year_introduced':'Year_Introduced', 'opening_date_clean':'Opening_Date', 'speed_mph':'Speed_mph',
                    'height_ft':'Height_ft', 'Inversions_clean':'Inversions', 'Gforce_clean':'Gforce'}, inplace = True)

df.head(20)
# Out:
#                               Coaster_Name              Length  \
# 0                       Switchback Railway      600 ft (180 m)
# 1                        Flip Flap Railway                 NaN
# 2   Switchback Railway (Euclid Beach Park)                 NaN
# 3             Loop the Loop (Coney Island)                 NaN
# 4             Loop the Loop (Young's Pier)                 NaN
# 5                           Cannon Coaster                 NaN
# 6                            Leap-The-Dips    1,452 ft (443 m)
# 7         Figure Eight (Euclid Beach Park)                 NaN
# 8                             Drop the Dip                 NaN
# 9       Scenic Railway (Euclid Beach Park)                 NaN
# 10          Loop the Loop (Olentangy Park)                 NaN
# 11                               Aero Dips                 NaN
# 12             Backety-Back Scenic Railway                 NaN
# 13             Racer (1910 roller coaster)  4,500 ft (1,400 m)
# ...

# %% [markdown]
# ### 5. Are there any duplicated rows?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There are no duplicate rows.

# %% [markdown]
# ### 6. What are the top 3 years with the most roller coasters introduced?

# %%
top = df.groupby('Opening_Date')['Coaster_Name'].count().sort_values(ascending = False).reset_index().head(3)
top
# Out:
#   Opening_Date  Coaster_Name
# 0   1999-01-01            10
# 1   2022-01-01             8
# 2   1998-01-01             7

# %% [markdown]
# #### 1999, 2022, and 1998 were the top three years with new rollercoasters introduced.

# %% [markdown]
# ### 7. What is the average speed? Also display a plot to show it's distribution.

# %%
df['Speed_mph'].mean()
# Out:
# 48.617289220917826

# %% [markdown]
# #### The average speed is 48.6 MPH

# %%
sns.histplot(data= df, x = 'Speed_mph')
plt.title('Distribution of Speed_mph')
plt.show()

# %% [markdown]
# ### 8. Explore the feature relationships. Are there any positively or negatively correlated relationships?

# %%
df.corr(numeric_only = True)
# Out:
#                  Inversions  Year_Introduced  latitude  longitude  \
# Inversions         1.000000         0.211003 -0.009815   0.061589
# Year_Introduced    0.211003         1.000000 -0.070982   0.175913
# latitude          -0.009815        -0.070982  1.000000  -0.298488
# longitude          0.061589         0.175913 -0.298488   1.000000
# speed1_value       0.163419         0.210191 -0.121847   0.301179
# Speed_mph          0.252209         0.204853 -0.063757   0.051063
# height_value       0.094811         0.087687 -0.004265  -0.092764
# Height_ft          0.171330         0.232150  0.011492   0.159733
# Inversions         1.000000         0.228758 -0.014043   0.087160
# Gforce             0.356865        -0.066657  0.042871   0.016485
#
#                  speed1_value  Speed_mph  height_value  Height_ft  Inversions  \
# Inversions           0.163419   0.252209      0.094811   0.171330    1.000000
# Year_Introduced      0.210191   0.204853      0.087687   0.232150    0.228758
# ...

# %% [markdown]
# #### Height and speed are positively correlated.

# %% [markdown]
# ### 9. Are there any rollercoasters that were introduced before 1950 that are still operating? What are their locations?

# %%
before_1950 = df[(df['Year_Introduced'] < 1950) & (df['Status'] == 'Operating')]
before_1950
# Out:
#                                       Coaster_Name                  Length  \
# 6                                    Leap-The-Dips        1,452 ft (443 m)
# 13                     Racer (1910 roller coaster)      4,500 ft (1,400 m)
# 15                        The Great Scenic Railway        967 m (3,173 ft)
# 22                         Jack Rabbit (Kennywood)        2,132 ft (650 m)
# 23                         Jack Rabbit (Seabreeze)        2,130 ft (650 m)
# 24                 Scenic Railway (roller coaster)        3,000 ft (910 m)
# 25                         Roller Coaster (Lagoon)        762 m (2,500 ft)
# 26           Big Dipper (Blackpool Pleasure Beach)      3,300 ft (1,000 m)
# 29                                    Giant Dipper        2,640 ft (800 m)
# 30                         Pippin (roller coaster)        3,250 ft (990 m)
# 32                       Thunderhawk (Dorney Park)        2,767 ft (843 m)
# ...
