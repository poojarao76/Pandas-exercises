# %% [markdown]
# Link to dataset: https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv

# %%
# import libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# read csv file
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %%
# to view all the columns
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %%
# to view shape of data
df.shape
# Out:
# (16, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
# to check for duplication
df.nunique()
# Out:
# Team                          16
# Goals                          8
# Shots on target               13
# Shots off target              13
# Shooting Accuracy             15
# % Goals-to-shots              14
# Total shots (inc. Blocked)    14
# Hit Woodwork                   5
# Penalty goals                  2
# Penalties not scored           2
# Headed goals                   4
# Passes                        16
# Passes completed              16
# Passing Accuracy              15
# Touches                       16
# Crosses                       14
# Dribbles                      15
# Corners Taken                 13
# Tackles                       14
# Clearances                    16
# Interceptions                 15
# Clearances off line            3
# Clean Sheets                   4
# Blocks                        10
# Goals conceded                 7
# Saves made                    10
# Saves-to-shots ratio          15
# Fouls Won                     13
# ...

# %%
# to view null values
df.isnull().sum()
# Out:
# Team                          0
# Goals                         0
# Shots on target               0
# Shots off target              0
# Shooting Accuracy             0
# % Goals-to-shots              0
# Total shots (inc. Blocked)    0
# Hit Woodwork                  0
# Penalty goals                 0
# Penalties not scored          0
# Headed goals                  0
# Passes                        0
# Passes completed              0
# Passing Accuracy              0
# Touches                       0
# Crosses                       0
# Dribbles                      0
# Corners Taken                 0
# Tackles                       0
# Clearances                    0
# Interceptions                 0
# Clearances off line           1
# Clean Sheets                  0
# Blocks                        0
# Goals conceded                0
# Saves made                    0
# Saves-to-shots ratio          0
# Fouls Won                     0
# Fouls Conceded                0
# ...

# %%
# stastical description of data
df.describe().T
# Out:
#                             count         mean          std     min      25%  \
# Goals                        16.0     4.750000     2.886751     1.0     2.75
# Shots on target              16.0    17.125000    10.582218     7.0     9.75
# Shots off target             16.0    24.937500    10.680005    10.0    18.00
# Total shots (inc. Blocked)   16.0    54.937500    26.065223    27.0    36.50
# Hit Woodwork                 16.0     1.250000     1.612452     0.0     0.00
# Penalty goals                16.0     0.187500     0.403113     0.0     0.00
# Penalties not scored         16.0     0.062500     0.250000     0.0     0.00
# Headed goals                 16.0     1.375000     1.024695     0.0     0.75
# Passes                       16.0  1763.375000   906.177898   851.0  1190.75
# Passes completed             16.0  1467.375000   827.580721   606.0   951.50
# Touches                      16.0  2579.187500  1122.164707  1433.0  1856.25
# ...

# %%
# stastical description of object dtype
df.describe(include = 'O')
# Out:
#            Team Shooting Accuracy % Goals-to-shots Passing Accuracy  \
# count        16                16               16               16
# unique       16                15               14               15
# top     Croatia             50.0%            16.0%            83.9%
# freq          1                 2                2                2
#
#        Saves-to-shots ratio
# count                    16
# unique                   15
# top                   66.7%
# freq                      2

# %% [markdown]
# ### 1. How many teams participated in the Euro2012?

# %%
df['Team'].nunique()
# Out:
# 16

# %% [markdown]
# #### Total 16 teams participated.

# %% [markdown]
# ### 2. What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# 35

# %% [markdown]
# ### 3. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline.

# %%
discipline = df[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### 4. Sort the teams by Red Cards, then to Yellow Cards.

# %%
df.sort_values(by = ['Red Cards', 'Yellow Cards'])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 2               Denmark      4               10                10
# 5               Germany     10               32                32
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# 15              Ukraine      2                7                26
# 4                France      3               22                24
# 12               Russia      5                9                31
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 0               Croatia      4               13                12
# 13                Spain     12               42                33
# 10             Portugal      6               22                42
# 7                 Italy      6               34                45
# ...

# %% [markdown]
# ### 5. Calculate the mean Yellow Cards given per Team.

# %%
df['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# #### The mean of yellow cards given per team is 7.44.

# %% [markdown]
# ### 6. Filter teams that scored more than 6 goals.

# %%
df[df['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                      0             2    2774              2427
# 13                     0             2    4317              3820
#
#    Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5             87.4%     3761      101        60             35       91
# 13            88.4%     5585       69       106             44      122
#
#     Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %% [markdown]
# ### 7. Select the teams that start with the letter G.

# %%
df[df['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                     0             2    2774              2427
# 6                     1             0    1187               911
#
#   Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5            87.4%     3761      101        60             35       91
# 6            76.7%     2016       52        53             10       65
#
#    Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %% [markdown]
# ### 8. Select the first 7 columns.

# %%
df.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 9. Select all columns except the last 3.

# %%
df.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 10. Present only the Shooting Accuracy from England, Italy and Russia.

# %%
countries = ['England', 'Italy', 'Russia']
filtered_df = df[df['Team'].isin(countries)]
shooting_accuracy = filtered_df[['Team', 'Shooting Accuracy']]
shooting_accuracy
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
